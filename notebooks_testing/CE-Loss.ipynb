# %%
from decifer_refactored.utility import (
    plot_loss_curves,
)
from glob import glob
from bin_refactored.train import TrainConfig

# ckpts = glob("../experiments/**/*.pt", recursive=True)

ckpts = [
    # "../experiments/no_conditioning_with_no_boundary_masking/ckpt.pt",
    # "../experiments/no_conditioning_with_boundary_masking/ckpt.pt",
    # "../experiments/conditioned_mlp_clean/ckpt.pt",
    # "../experiments/conditioned_mlp_augmentation/ckpt.pt",
    # "../experiments/conditioned_cl_augmentation/ckpt.pt",
    # "../experiments/conditioned_mlp_augmentation_large/ckpt.pt",
    # "../experiments/cond_mlp_aug_3_layer/ckpt.pt",
    # "../experiments/cond_mlp_clean_5pctfwhm/ckpt.pt",
    "../experiments/model__conditioned_mlp_augmentation__context_3076/ckpt.pt",
    "../experiments/model__nocond__context_3076/ckpt.pt",
    # "../experiments/model__conditioned_mlp_augmentation__context_3076__embd_1024/ckpt.pt",
]

plot_loss_curves(
    ckpts,
    ylog = False,
    # xmax = 1000,
    ymin = 0.1,
    ymax = 0.3,
    figsize=(10,5),
)
