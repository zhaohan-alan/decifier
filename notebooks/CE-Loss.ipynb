# %%
from decifer.utility import (
    plot_loss_curves,
)
from glob import glob

# ckpts = glob("../experiments/**/*.pt", recursive=True)

ckpts = [
    "../experiments/nocond_boundarymasking/ckpt.pt",
    "../experiments/nocond_noboundarymasking/ckpt.pt",
    "../experiments/cl_vs_mlp/cond_mlp_noaug_v1/ckpt.pt",
    "../experiments/cl_vs_mlp/cond_cl_noaug/ckpt.pt",
]

plot_loss_curves(
    ckpts,
    ylog = False,
    # xmax = 1000,
    ymin = 0.15,
    ymax = 0.3,
    figsize=(10,5),
)
