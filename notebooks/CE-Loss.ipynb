# %%
from decifer.utility import (
    plot_loss_curves,
)
from glob import glob

# ckpts = glob("../experiments/**/*.pt", recursive=True)

ckpts = [
    "../experiments_11nov24/no_conditioning_with_no_boundary_masking/ckpt.pt",
    "../experiments_11nov24/no_conditioning_with_boundary_masking/ckpt.pt",
    "../experiments_11nov24/conditioning_mlp_clean/ckpt.pt",
    "../experiments_11nov24/conditioning_mlp_augmentation/ckpt.pt",
    "../experiments_11nov24/conditioning_cl_augmentation/ckpt.pt",
    "../experiments_11nov24/conditioning_mlp_augmentation_large/ckpt.pt",
]

plot_loss_curves(
    ckpts,
    ylog = False,
    # xmax = 1000,
    ymin = 0.15,
    ymax = 0.3,
    figsize=(10,5),
)
