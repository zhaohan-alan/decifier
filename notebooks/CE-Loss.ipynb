# %%
from decifer.utility import (
    plot_loss_curves,
)
from glob import glob

# ckpts = glob("../experiments/**/*.pt", recursive=True)

ckpts = [
    # "../experiments/cross-contamination/crystal_full_models/no_boundary_masking/ckpt.pt",
    # "../experiments/cross-contamination/crystal_full_models/boundary_masking/ckpt.pt",
    # "../experiments/cross-contamination/crystal_full_models/attn_bias_position_resetting/ckpt.pt",
    # "../experiments/cl_vs_mlp/cond_cl_noaug/ckpt.pt",
    # "../experiments/cl_vs_mlp/cond_mlp_noaug_v1/ckpt.pt",
    # "../experiments/cl_vs_mlp/cond_mlp_aug/ckpt.pt",
    "../testing_refactored/ckpt.pt",
    "../testing_refactored_nocond/ckpt.pt",
    "../testing_refactored_cl_emb/ckpt.pt",
]

plot_loss_curves(
    ckpts,
    ylog = False,
    xmax = 1000,
    # ymin = 0.1,
    # ymax = 0.3,
    figsize=(10,5),
)
